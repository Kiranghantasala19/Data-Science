# %%
import pickle
with open("model_cnn.pkl", "rb") as f:
    model= pickle.load(f)

# %%
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt

# Load image and convert to grayscale
img = Image.open(r"C:\Users\KIRAN GHANTASALA\Downloads\WhatsApp Image 2026-02-17 at 09.18.50.jpeg").convert("L")

# Invert colors (MNIST digits are white on black)
plt.imshow(img, cmap='gray') 
plt.axis('off') 
plt.show()

# %%
# Resize to 28x28
img = img.resize((28, 28))

# Convert to array and normalize
img_array = np.array(img) / 255.0

# Reshape for CNN input
img_array = img_array.reshape(1, 28, 28, 1)

# %%
plt.imshow(img, cmap='gray') 
plt.axis('off') 
plt.show()
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)
print("Predicted digit:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Predicted digit: 4

# %%
# Load image and convert to grayscale
img = Image.open(r"C:\Users\KIRAN GHANTASALA\OneDrive\Pictures\Screenshots\Screenshot 2026-02-17 084626.png").convert("L")

plt.imshow(img, cmap='gray') 
plt.axis('off') 
plt.show()

# Resize to 28x28
img = img.resize((28, 28))

# Convert to array and normalize
img_array = np.array(img) / 255.0

# Reshape for CNN input
img_array = img_array.reshape(1, 28, 28, 1)

plt.imshow(img, cmap='gray') 
plt.axis('off') 
plt.show()

prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)
print("Predicted digit:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Predicted digit: 2

# %%
# Load image and convert to grayscale
img = Image.open(r"C:\Users\KIRAN GHANTASALA\Downloads\WhatsApp Image 2026-02-17 at 09.18.50 (1).jpeg").convert("L")

plt.imshow(img, cmap='gray') 
plt.axis('off') 
plt.show()

# Resize to 28x28
img = img.resize((28, 28))

# Convert to array and normalize
img_array = np.array(img) / 255.0

# Reshape for CNN input
img_array = img_array.reshape(1, 28, 28, 1)

plt.imshow(img, cmap='gray') 
plt.axis('off') 
plt.show()

prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)
print("Predicted digit:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Predicted digit: 6
